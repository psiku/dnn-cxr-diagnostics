# %% [markdown]
# ### Imports

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Load kedro

# %%
import os

os.chdir("../../")

# %load_ext kedro.ipython
# Out:
# [03/28/26 22:40:03] INFO     Using                                                                  ]8;id=901277;file://c:\Users\barte\OneDrive\Pulpit\dnn-cxr-diagnostics\.venv\Lib\site-packages\kedro\framework\project\__init__.py\__init__.py]8;;\:]8;id=9406;file://c:\Users\barte\OneDrive\Pulpit\dnn-cxr-diagnostics\.venv\Lib\site-packages\kedro\framework\project\__init__.py#269\269]8;;\
#                              'c:\Users\barte\OneDrive\Pulpit\dnn-cxr-diagnostics\.venv\Lib\site-pac
#                              kages\kedro\framework\project\rich_logging.yml' as logging
#                              configuration.
# ...

# %% [markdown]
# ### Loading results

# %%
best_thresholds = catalog.load("best_thresholds")
test_metrics_default = catalog.load("test_metrics_default")
test_metrics_tuned = catalog.load("test_metrics_tuned")
test_metrics_comparison = catalog.load("test_metrics_comparison")
test_per_class_comparison = catalog.load("test_per_class_comparison")
# Out:
# [03/28/26 22:41:53] INFO     Loading data from best_thresholds (JSONDataset)...                ]8;id=540655;file://c:\Users\barte\OneDrive\Pulpit\dnn-cxr-diagnostics\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=859517;file://c:\Users\barte\OneDrive\Pulpit\dnn-cxr-diagnostics\.venv\Lib\site-packages\kedro\io\data_catalog.py#1048\1048]8;;\
#                     INFO     Loading data from test_metrics_default (JSONDataset)...           ]8;id=816504;file://c:\Users\barte\OneDrive\Pulpit\dnn-cxr-diagnostics\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=382189;file://c:\Users\barte\OneDrive\Pulpit\dnn-cxr-diagnostics\.venv\Lib\site-packages\kedro\io\data_catalog.py#1048\1048]8;;\
# ...

# %%
best_thresholds
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# {
#     'Infiltration': 0.62,
#     'Effusion': 0.77,
#     'Atelectasis': 0.74,
#     'Nodule': 0.38,
#     'Mass': 0.44,
#     'Pneumothorax': 0.43,
#     'Consolidation': 0.68,
#     'Pleural_Thickening': 0.47000000000000003,
#     'Cardiomegaly': 0.45,
#     'Emphysema': 0.3,
#     'Edema': 0.5700000000000001,
#     'Fibrosis': 0.24000000000000002,
#     'Pneumonia': 0.32,
#     'Hernia': 0.2
# }

# %%
test_metrics_default
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# {
#     'f1_macro': 0.08127488196699888,
#     'f1_micro': 0.22439883492515073,
#     'precision_macro': 0.047544997286771765,
#     'precision_micro': 0.13754733275758985,
#     'recall_macro': 0.3469236022329322,
#     'recall_micro': 0.6088362861133574,
#     'auroc_macro': 0.5557446720602883,
#     'ap_macro': 0.09381726817085746
# }

# %%
test_metrics_tuned
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# {
#     'f1_macro': 0.09001897444977436,
#     'f1_micro': 0.17962692868657404,
#     'precision_macro': 0.09576734415100081,
#     'precision_micro': 0.1879367119106899,
#     'recall_macro': 0.09867834363331392,
#     'recall_micro': 0.17202087774755567,
#     'auroc_macro': 0.5557446720602883,
#     'ap_macro': 0.09381726817085746
# }

# %%
test_metrics_comparison
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#             metric  default_0_5     tuned     delta
# 0         f1_macro     0.081275  0.090019  0.008744
# 1         f1_micro     0.224399  0.179627 -0.044772
# 2  precision_macro     0.047545  0.095767  0.048222
# 3  precision_micro     0.137547  0.187937  0.050389
# 4     recall_macro     0.346924  0.098678 -0.248245
# 5     recall_micro     0.608836  0.172021 -0.436815
# 6      auroc_macro     0.555745  0.555745  0.000000
# 7         ap_macro     0.093817  0.093817  0.000000

# %%
test_per_class_comparison
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#             class_name  f1_default_0_5  precision_default_0_5  \
# 0         Infiltration        0.385788               0.239343
# 1             Effusion        0.310029               0.183627
# 2          Atelectasis        0.228019               0.128864
# 3               Nodule        0.000000               0.000000
# 4                 Mass        0.000000               0.000000
# 5         Pneumothorax        0.000000               0.000000
# 6        Consolidation        0.134557               0.072228
# 7   Pleural_Thickening        0.000000               0.000000
# 8         Cardiomegaly        0.000000               0.000000
# 9            Emphysema        0.000000               0.000000
# 10               Edema        0.079456               0.041569
# 11            Fibrosis        0.000000               0.000000
# ...
